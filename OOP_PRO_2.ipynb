# %%
import random

# %%
class Person():

  NAMES = ["Иван", "Петр", "Николай","Андрей", "Тимофей", "Сергей",
             "Дмитрий", "Алексей", "Владимир", "Борис", "Глеб",
             "Семен", "Степан", "Кондрат", "Игнат", "Иннокентий",
             "Трофим", "Терентий", "Кирилл", "Серафим", "Александр"]

  def __init__(self):
   self.name= Person.randname()
 

  def __str__(self):
    s=self.name
    return s

  def randname():
    rname=random.choice(Person.NAMES)
    return rname

  
def main():

  person=Person()
  print(person)

main()
# Out:
# Сергей

# %%
class Person():

  NAMES = ["Иван", "Петр", "Николай","Андрей", "Тимофей", "Сергей",
             "Дмитрий", "Алексей", "Владимир", "Борис", "Глеб",
             "Семен", "Степан", "Кондрат", "Игнат", "Иннокентий",
             "Трофим", "Терентий", "Кирилл", "Серафим", "Александр"]
  FNAME_SFX = "ович"   

  def __init__(self):
   self.name, self.fname= Person.randname()

  def __str__(self):
    s=self.name +" "+ self.fname
    return s

  def randname():
    rname=random.choice(Person.NAMES)

    fname_prx=random.choice(Person.NAMES)
    if fname_prx[-1] == "й":
        rfname = fname_prx.rstrip('й') + 'e' + Person.FNAME_SFX[1:]
    else:
        rfname = fname_prx + Person.FNAME_SFX
    return rname ,rfname

  
def main():

  person=Person()
  print(person)

main()
# Out:
# Владимир Иннокентиeвич

# %%
class Person():

  NAMES = ["Иван", "Петр", "Николай","Андрей", "Тимофей", "Сергей",
             "Дмитрий", "Алексей", "Владимир", "Борис", "Глеб",
             "Семен", "Степан", "Кондрат", "Игнат", "Иннокентий",
             "Трофим", "Терентий", "Кирилл", "Серафим", "Александр"]
  FNAME_SFX = "ович" 
  LNAME_SFX = ["ов", "овский", "енко", "ович"]  

  def __init__(self):
   self.name, self.fname, self.lname= Person.randname()

  def __str__(self):
    s=self.name +" "+ self.fname+" "+self.lname
    return s

  def randname():
    rname=random.choice(Person.NAMES)

    fname_prx=random.choice(Person.NAMES)
    if fname_prx[-1] == "й":
        rfname = fname_prx.rstrip('й') + 'e' + Person.FNAME_SFX[1:]
    else:
        rfname = fname_prx + Person.FNAME_SFX

    lname_prx=random.choice(Person.NAMES)
    lname_sfx=random.choice(Person.LNAME_SFX)
    if lname_prx[-1] == "й":
         rlname = lname_prx.rstrip('й') + 'e' + lname_sfx[1:]
    else:
         rlname = lname_prx + lname_sfx

    return rname ,rfname,rlname


  
def main():

  person=Person()
  print(person)

main()
# Out:
# Кондрат Владимирович Дмитриeвич

# %%
class Person():

  NAMES = ["Иван", "Петр", "Николай","Андрей", "Тимофей", "Сергей",
             "Дмитрий", "Алексей", "Владимир", "Борис", "Глеб",
             "Семен", "Степан", "Кондрат", "Игнат", "Иннокентий",
             "Трофим", "Терентий", "Кирилл", "Серафим", "Александр"]
  FNAME_SFX = "ович" 
  LNAME_SFX = ["ов", "овский", "енко", "ович"]  

  def __init__(self):
   self.name, self.fname, self.lname= Person.randname()

  def __str__(self):
    s=self.name +" "+ self.fname+" "+self.lname
    return s

  def randname():
    rname=random.choice(Person.NAMES)

    fname_prx=random.choice(Person.NAMES)
    if fname_prx[-1] == "й":
        rfname = fname_prx.rstrip('й') + 'e' + Person.FNAME_SFX[1:]
    else:
        rfname = fname_prx + Person.FNAME_SFX

    lname_prx=random.choice(Person.NAMES)
    lname_sfx=random.choice(Person.LNAME_SFX)
    if lname_prx[-1] == "й":
         rlname = lname_prx.rstrip('й') + 'e' + lname_sfx[1:]
    else:
         rlname = lname_prx + lname_sfx

    return rname ,rfname,rlname


  
def main():

  person=Person()
  print(person)

  person1=Person()
  print(person1)

main()
# Out:
# Кондрат Сергеeвич Иванов
# Иннокентий Андреeвич Борисович

# %%
class Person():

  NAMES = ["Иван", "Петр", "Николай","Андрей", "Тимофей", "Сергей",
             "Дмитрий", "Алексей", "Владимир", "Борис", "Глеб",
             "Семен", "Степан", "Кондрат", "Игнат", "Иннокентий",
             "Трофим", "Терентий", "Кирилл", "Серафим", "Александр"]
  FNAME_SFX = "ович" 
  LNAME_SFX = ["ов", "овский", "енко", "ович"]  

  def __init__(self):
   self.name, self.fname, self.lname= Person.randname()

  def __str__(self):
    s=self.name +" "+ self.fname+" "+self.lname
    return s

  def randname():
    rname=random.choice(Person.NAMES)

    fname_prx=random.choice(Person.NAMES)
    if fname_prx[-1] == "й":
        rfname = fname_prx.rstrip('й') + 'e' + Person.FNAME_SFX[1:]
    else:
        rfname = fname_prx + Person.FNAME_SFX

    lname_prx=random.choice(Person.NAMES)
    lname_sfx=random.choice(Person.LNAME_SFX)
    if lname_prx[-1] == "й":
         rlname = lname_prx.rstrip('й') + 'e' + lname_sfx[1:]
    else:
         rlname = lname_prx + lname_sfx

    return rname ,rfname,rlname


  
def main():

  persons = []
  for i in range(9):
      persons.append(Person())
  for i in persons:
        print(i)

main()
# Out:
# Кирилл Кондратович Александренко
# Степан Кириллович Кириллов
# Андрей Серафимович Александровский
# Тимофей Николаeвич Борисов
# Алексей Кириллович Борисенко
# Владимир Степанович Николаeнко
# Терентий Семенович Терентиeв
# Игнат Иванович Серафименко
# Владимир Алексеeвич Иваненко

# %%
class Person():

  NAMES = ["Иван", "Петр", "Николай","Андрей", "Тимофей", "Сергей",
             "Дмитрий", "Алексей", "Владимир", "Борис", "Глеб",
             "Семен", "Степан", "Кондрат", "Игнат", "Иннокентий",
             "Трофим", "Терентий", "Кирилл", "Серафим", "Александр"]
  FNAME_SFX = "ович" 
  LNAME_SFX = ["ов", "овский", "енко", "ович"]  

  def __init__(self):
   self.name, self.fname, self.lname= Person.randname()
   self.year=str(random.randint(1945,2000))

  def __str__(self):
    s=self.name +" "+ self.fname+" "+self.lname +" " +self.year +" г.р" +"\n"
    return s

  def randname():
    rname=random.choice(Person.NAMES)

    fname_prx=random.choice(Person.NAMES)
    if fname_prx[-1] == "й":
        rfname = fname_prx.rstrip('й') + 'e' + Person.FNAME_SFX[1:]
    else:
        rfname = fname_prx + Person.FNAME_SFX

    lname_prx=random.choice(Person.NAMES)
    lname_sfx=random.choice(Person.LNAME_SFX)
    if lname_prx[-1] == "й":
         rlname = lname_prx.rstrip('й') + 'e' + lname_sfx[1:]
    else:
         rlname = lname_prx + lname_sfx

    return rname ,rfname,rlname


  
def main():

  persons = []
  for i in range(9):
      persons.append(Person())
  for i in persons:
        print(i)

main()
# Out:
# Сергей Трофимович Глебенко 1969 г.р
#
# Глеб Сергеeвич Иннокентиeв 1984 г.р
#
# Терентий Николаeвич Иванович 1951 г.р
#
# Глеб Александрович Терентиeвич 1946 г.р
#
# Андрей Глебович Кондратов 1998 г.р
#
# Владимир Иванович Владимировский 1970 г.р
#
# Иван Сергеeвич Иннокентиeнко 1991 г.р
#
# Трофим Николаeвич Кондратов 1953 г.р
#
# Сергей Петрович Кондратович 1962 г.р

# %%
class Person():

  NAMES = ["Иван", "Петр", "Николай","Андрей", "Тимофей", "Сергей",
             "Дмитрий", "Алексей", "Владимир", "Борис", "Глеб",
             "Семен", "Степан", "Кондрат", "Игнат", "Иннокентий",
             "Трофим", "Терентий", "Кирилл", "Серафим", "Александр"]
  FNAME_SFX = "ович" 
  LNAME_SFX = ["ов", "овский", "енко", "ович"]  
  BPLACE0 = ["с. ", "пос. ", "ПГТ "]
  BPLACE1 = ["Большие ", "Малые ", "Старые ", "Новые ", "Красные ", 
               "Южные ", "Северные ", "Ленинские ", "Дальние ", "Тощие "]
  BPLACE2 = ["Стыды", "Пипки", "Серпы", "Хутора", "Пикули", "Дали", "Рассветы",
               "Сады", "Зады", "Нюни", "Пруды", "Заветы"]
    

  def __init__(self):
   self.name, self.fname, self.lname= Person.randname()
   self.year=str(random.randint(1945,2000))
   self.bplace = random.choice(Person.BPLACE0)+\
                      random.choice(Person.BPLACE1)+\
                      random.choice(Person.BPLACE2)
        
   self.snils = str(random.randint(100,999))+"-"+\
                     str(random.randint(100,999))+"-"+\
                     str(random.randint(100,999))+"-"+\
                     str(random.randint(10,99))
        
   inn = "" + str(random.randint(1,9))
   for i in range(11):
      inn += str(random.randint(0,9))
      self.inn = inn

  def __str__(self):
    s=self.name +" "+ self.fname+" "+self.lname +" " +self.year +" г.р" +"\n"+\
            "уроженец " + self.bplace + '\n'+\
            "СНИЛС:\t" + self.snils+'\n'+\
            "ИНН:\t" + self.inn+'\n\n'
    return s

  def randname():
    rname=random.choice(Person.NAMES)

    fname_prx=random.choice(Person.NAMES)
    if fname_prx[-1] == "й":
        rfname = fname_prx.rstrip('й') + 'e' + Person.FNAME_SFX[1:]
    else:
        rfname = fname_prx + Person.FNAME_SFX

    lname_prx=random.choice(Person.NAMES)
    lname_sfx=random.choice(Person.LNAME_SFX)
    if lname_prx[-1] == "й":
         rlname = lname_prx.rstrip('й') + 'e' + lname_sfx[1:]
    else:
         rlname = lname_prx + lname_sfx

    return rname ,rfname,rlname


  
def main():

  persons = []
  for i in range(9):
      persons.append(Person())
  for i in persons:
        print(i)

main()
# Out:
# Иннокентий Иннокентиeвич Терентиeнко 1954 г.р
# уроженец пос. Красные Стыды
# СНИЛС:	313-226-162-18
# ИНН:	437182337540
#
#
# Андрей Алексеeвич Кондратовский 1991 г.р
# уроженец ПГТ Ленинские Серпы
# СНИЛС:	164-527-961-62
# ИНН:	304844704280
#
#
# Кирилл Борисович Сергеeвский 1949 г.р
# уроженец с. Малые Пруды
# СНИЛС:	892-812-516-33
# ИНН:	507120436437
#
#
# Дмитрий Степанович Петровский 1957 г.р
# уроженец с. Малые Серпы
# СНИЛС:	830-515-202-59
# ИНН:	637270254486
#
#
# Николай Петрович Игнатенко 1980 г.р
# уроженец пос. Северные Пикули
# СНИЛС:	781-444-980-21
# ИНН:	709449166062
#
#
# Игнат Николаeвич Терентиeнко 1983 г.р
# уроженец с. Тощие Дали
# СНИЛС:	588-277-882-15
# ИНН:	594899075228
#
#
# Алексей Глебович Тимофеeнко 1955 г.р
# уроженец ПГТ Дальние Стыды
# СНИЛС:	722-973-935-12
# ИНН:	776406958272
#
#
# Тимофей Николаeвич Кириллов 1960 г.р
# уроженец пос. Южные Хутора
# СНИЛС:	542-803-231-37
# ИНН:	483649045842
#
#
# Тимофей Тимофеeвич Трофименко 1992 г.р
# уроженец пос. Новые Пипки
# СНИЛС:	715-446-959-53
# ИНН:	303008521804

# %%
class Person():

  NAMES = ["Иван", "Петр", "Николай","Андрей", "Тимофей", "Сергей",
             "Дмитрий", "Алексей", "Владимир", "Борис", "Глеб",
             "Семен", "Степан", "Кондрат", "Игнат", "Иннокентий",
             "Трофим", "Терентий", "Кирилл", "Серафим", "Александр"]
  FNAME_SFX = "ович" 
  LNAME_SFX = ["ов", "овский", "енко", "ович"]  
  BPLACE0 = ["с. ", "пос. ", "ПГТ "]
  BPLACE1 = ["Большие ", "Малые ", "Старые ", "Новые ", "Красные ", 
               "Южные ", "Северные ", "Ленинские ", "Дальние ", "Тощие "]
  BPLACE2 = ["Стыды", "Пипки", "Серпы", "Хутора", "Пикули", "Дали", "Рассветы",
               "Сады", "Зады", "Нюни", "Пруды", "Заветы"]
    

  def __init__(self):
   self.name, self.fname, self.lname= Person.randname()
   self.year=str(random.randint(1945,2000))
   self.bplace = random.choice(Person.BPLACE0)+\
                      random.choice(Person.BPLACE1)+\
                      random.choice(Person.BPLACE2)
        
   self.snils = str(random.randint(100,999))+"-"+\
                     str(random.randint(100,999))+"-"+\
                     str(random.randint(100,999))+"-"+\
                     str(random.randint(10,99))
        
   inn = "" + str(random.randint(1,9))
   for i in range(11):
      inn += str(random.randint(0,9))
      self.inn = inn

  def __str__(self):
    s=self.name +" "+ self.fname+" "+self.lname +" " +self.year +" г.р" +"\n"+\
            "уроженец " + self.bplace + '\n'+\
            "СНИЛС:\t" + self.snils+'\n'+\
            "ИНН:\t" + self.inn+'\n\n'
    return s

  def randname():
    rname=random.choice(Person.NAMES)

    fname_prx=random.choice(Person.NAMES)
    if fname_prx[-1] == "й":
        rfname = fname_prx.rstrip('й') + 'e' + Person.FNAME_SFX[1:]
    else:
        rfname = fname_prx + Person.FNAME_SFX

    lname_prx=random.choice(Person.NAMES)
    lname_sfx=random.choice(Person.LNAME_SFX)
    if lname_prx[-1] == "й":
         rlname = lname_prx.rstrip('й') + 'e' + lname_sfx[1:]
    else:
         rlname = lname_prx + lname_sfx

    return rname ,rfname,rlname

class Student(Person):
    def __init__(self):
        super().__init__()
        UNIVS = ["UrFU", "MSU", "DONNTU"]
        self.univ = random.choice(UNIVS)
        
    def __str__(self):
        s = super().__str__()
        s += "Студент "+ self.univ + "\n"
        return s
        
  
def main():

  persons = []
  for i in range(9):
      persons.append(Person())
  for i in persons:
        print(i)
  students = []
  for i in range(10):
      students.append(Student())
    
  for i in students:
      print(i)
main()
# Out:
# Тимофей Терентиeвич Кондратенко 1966 г.р
# уроженец ПГТ Северные Дали
# СНИЛС:	725-915-494-65
# ИНН:	495122375471
#
#
# Кондрат Андреeвич Глебовский 1970 г.р
# уроженец с. Малые Пипки
# СНИЛС:	563-651-266-91
# ИНН:	729139063947
#
#
# Петр Иванович Терентиeнко 1981 г.р
# уроженец с. Северные Серпы
# СНИЛС:	675-771-125-34
# ИНН:	876517669336
#
#
# Терентий Дмитриeвич Степанович 1990 г.р
# уроженец ПГТ Южные Хутора
# СНИЛС:	745-486-377-24
# ИНН:	394032395347
#
#
# Кондрат Сергеeвич Андреeв 1994 г.р
# уроженец с. Новые Сады
# СНИЛС:	206-499-907-54
# ИНН:	731093259164
#
#
# Терентий Андреeвич Андреeвич 1990 г.р
# уроженец ПГТ Дальние Стыды
# СНИЛС:	899-711-528-95
# ИНН:	425406540813
#
#
# Серафим Тимофеeвич Семенов 2000 г.р
# уроженец с. Дальние Нюни
# СНИЛС:	683-247-333-17
# ИНН:	330667489359
#
#
# Семен Иннокентиeвич Игнатовский 2000 г.р
# уроженец пос. Южные Хутора
# СНИЛС:	951-396-786-39
# ИНН:	773731549162
#
#
# Сергей Иванович Николаeнко 1995 г.р
# уроженец пос. Новые Сады
# СНИЛС:	997-399-208-73
# ИНН:	302788881446
#
#
# Владимир Владимирович Борисович 1954 г.р
# уроженец пос. Большие Стыды
# СНИЛС:	347-372-112-79
# ИНН:	851734868155
#
# Студент MSU
#
# Иван Кириллович Александровский 1995 г.р
# уроженец пос. Тощие Серпы
# СНИЛС:	124-489-518-15
# ИНН:	600881727643
#
# Студент DONNTU
#
# Терентий Николаeвич Кондратовский 1948 г.р
# уроженец пос. Дальние Нюни
# СНИЛС:	538-105-207-92
# ИНН:	300385902544
#
# Студент DONNTU
#
# Тимофей Кондратович Сергеeвич 1961 г.р
# уроженец пос. Красные Серпы
# СНИЛС:	575-853-485-64
# ИНН:	728085797077
#
# Студент DONNTU
#
# Кондрат Николаeвич Николаeвич 2000 г.р
# уроженец ПГТ Дальние Сады
# СНИЛС:	930-177-406-24
# ИНН:	603496680444
#
# Студент DONNTU
#
# Сергей Петрович Владимирович 1998 г.р
# уроженец с. Новые Пипки
# СНИЛС:	758-274-683-19
# ИНН:	343511227741
#
# Студент MSU
#
# Сергей Александрович Тимофеeвский 1951 г.р
# уроженец с. Новые Сады
# СНИЛС:	200-121-506-53
# ИНН:	880311989836
#
# Студент UrFU
#
# Владимир Николаeвич Тимофеeвич 1974 г.р
# уроженец ПГТ Старые Стыды
# СНИЛС:	658-807-463-72
# ИНН:	487963403374
#
# Студент UrFU
#
# Кондрат Игнатович Александренко 1967 г.р
# уроженец с. Большие Сады
# СНИЛС:	701-900-521-16
# ИНН:	837405856473
#
# Студент UrFU
#
# Александр Алексеeвич Трофимов 1998 г.р
# уроженец ПГТ Ленинские Рассветы
# СНИЛС:	407-485-600-98
# ИНН:	161280774696
#
# Студент UrFU
